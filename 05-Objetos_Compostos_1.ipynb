# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Quais as vantagens da utilização de objetos compostos em detrimento dos objetos simples?

# %% [markdown]
# #R: Objetos compostos agrupam conjuntos de objetos simples, além de permitirem a indexação e organização destes conjuntos. Isso melhora a organização, eficiência e encapsulamento do código

# %% [markdown]
# ## 02 – Instancie uma variável da classe tupla, contendo 5 valores de qualquer classe, e recupere os valores:

# %%
tupla = ('t', 'u', 'p', 'l', 'a')
tupla
# Out:
# ('t', 'u', 'p', 'l', 'a')

# %% [markdown]
# ## 03 – Instancie uma variável da classe lista, contendo 5 valores de qualquer classe, e recupere cada um dos valores:

# %%
lista = ['l', 'i', 's', 't', 'a']
lista
# Out:
# ['l', 'i', 's', 't', 'a']

# %% [markdown]
# ## 04 – Instancie uma variável da classe lista, contendo 5 nomes de genes diferentes, recupere de cada um dos valores quantas letras ‘a’ estão presentes:

# %%
lista_genes = ['Heat shock protein 70','histone H2B','cytochrome c oxidase subunit 1','actin','18S ribosomal RNA']
lista_genes[0].count('a') #posso fazer isso para cada índice da lista

#ou 

for gene in lista_genes:
    print(gene.lower().count('a')) #lower() para contar tanto 'a' quanto 'A'
# Out:
# 1
# 0
# 1
# 1
# 2

# %% [markdown]
# ## 05 – Instancie uma variável da classe lista, contendo 5 valores, e recupere do segundo ao quarto valores:

# %%
lista = ['l', 'i', 's', 't', 'a']
lista[1:4]
# Out:
# ['i', 's', 't']

# %% [markdown]
# ## 06 – Instancie uma variável da classe string com o seu nome como valor, e recupere o segundo e o último valores:

# %%
nome = 'Mateus'
nome[1], nome[-1]
# Out:
# ('a', 's')

# %% [markdown]
# ## 07 – Instancie uma variável da classe dicionário com quantos valores inteiros desejar. Usando as funções globais, retorne a classe do objeto, quantos valores estão instanciados e a soma dos valores contidos no objeto:

# %%
dicio = {'dia': 28, 'mês': 2, 'ano': 2000, 'idade': 26}
print(type(dicio))
print(len(dicio))
print(sum(dicio.values()))
# Out:
# <class 'dict'>
# 4
# 2056

# %% [markdown]
# ## 08 – Instancie uma variável da classe dicionário. Os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes de genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser o número de caracteres em cada index. Retorne o objeto:

# %%
#dic_genes = {'Heat shock protein 70': len('Heat shock protein 70'), 'histone H2B': len('histone H2B'), 'cytochrome c oxidase subunit 1': len('cytochrome c oxidase subunit 1'), 'actin': len('actin'), '18S ribosomal RNA': len('18S ribosomal RNA')}

for i in range(len(lista_genes)):
    print(f'{lista_genes[i]}: {len(lista_genes[i])}')
# Out:
# Heat shock protein 70: 21
# histone H2B: 11
# cytochrome c oxidase subunit 1: 30
# actin: 5
# 18S ribosomal RNA: 17

# %% [markdown]
# ## 09 – Instancie cinco variáveis da classe lista. Cada uma delas será referente à um dos valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Em cada uma das listas, você deve inserir o número de caracteres presentes no nome do gene, os dois primeiros caracteres do nome, quantas vezes aparece o caractere ‘a’ e se no nome aparecem os caracteres ‘hu’. Para isso você deve utilizar a indexação de lista. Retorne cada um dos objetos:

# %%
lista_genes = ['Heat shock protein 70','histone H2B','cytochrome c oxidase subunit 1','actin','18S ribosomal RNA'] 

HSP70 = lista_genes[0]
H2B = lista_genes[1]
CCO1 = lista_genes[2]
ACTIN = lista_genes[3]
RIBOSOMAL_RNA = lista_genes[4]

print(len(HSP70),HSP70[0:2] ,HSP70.lower().count('a'), 'hu' in HSP70.lower())
print(len(H2B),H2B[0:2] ,H2B.lower().count('a'), 'hu' in H2B.lower())
print(len(CCO1),CCO1[0:2] ,CCO1.lower().count('a'), 'hu' in CCO1.lower())
print(len(ACTIN),ACTIN[0:2] ,ACTIN.lower().count('a'), 'hu' in ACTIN.lower())
print(len(RIBOSOMAL_RNA),RIBOSOMAL_RNA[0:2] ,RIBOSOMAL_RNA.lower().count('a'), 'hu' in RIBOSOMAL_RNA.lower())

#só vi depois que aqui não criei listas para cada gene, mas sim variáveis. O resultado foi equivalente, então vou manter aqui como uma resposta alternativa. De qualquer forma, isso gerou os dados pedidos para cada lista.
# Out:
# 21 He 1 False
# 11 hi 0 False
# 30 cy 1 False
# 5 ac 1 False
# 17 18 2 False

# %%
hsp70 = [21, 'He', 1, False]
h2b = [11, 'hi', 0, False]
cco1 = [30, 'cy', 1, False]
actin = [5, 'ac', 1, False]
ribosomal_rna = [17, '18', 2, False]

print(hsp70)
print(h2b)
print(cco1)
print(actin)
print(ribosomal_rna)
# Out:
# [21, 'He', 1, False]
# [11, 'hi', 0, False]
# [30, 'cy', 1, False]
# [5, 'ac', 1, False]
# [17, '18', 2, False]

# %% [markdown]
# ## 10 – Instancie uma variável da classe dicionário, os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser as listas instanciadas no exercício 9. Retorne o objeto.

# %%
dic = {
    lista_genes[0]: hsp70,
    lista_genes[1]: h2b,
    lista_genes[2]: cco1,
    lista_genes[3]: actin,
    lista_genes[4]: ribosomal_rna
}

for i in dic:
    print(f'{i}: {dic[i]}')
# Out:
# Heat shock protein 70: [21, 'He', 1, False]
# histone H2B: [11, 'hi', 0, False]
# cytochrome c oxidase subunit 1: [30, 'cy', 1, False]
# actin: [5, 'ac', 1, False]
# 18S ribosomal RNA: [17, '18', 2, False]
