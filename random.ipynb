# %%
import numpy as np
import pandas as pd

# %%
simbolo = [
    'IFNG',
    'Il10',
    'Tnf',
    'CSF2'
]
full_name = [
    'interferon gamma',
    'interleukin 10',
    'tumor necrosis factor',
    'colony stimulating factor 2'
]
source = [
    'HGNC:HGNC:5438',
    'RGD:2886',
    'MGI:MGI:104798',
    'HGNC:HGNC:2434'
]
gene_type = [
    'protein coding',
    'protein coding',
    'protein coding',
    'protein coding'
]
organism = [
    'Homo sapiens',
    'Rattus norvegicus',
    'Mus musculus',
    'Homo sapiens'
]
chromosome = [
    12,
    13,
    17,
    5
]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]
gene_matriz_lista
# Out:
# [['IFNG', 'Il10', 'Tnf', 'CSF2'],
#  ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  ['protein coding', 'protein coding', 'protein coding', 'protein coding'],
#  ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %%
# as chaves serão os nomes das listas em string e os valores das listas
dicionario = {
"simbolo" : simbolo ,
"full_name" : full_name,
"source" : source,
"gene_type" : gene_type,
"organism" : organism,
"chromosome" : chromosome

}

dicionario ['simbolo']
# Out:
# ['IFNG', 'Il10', 'Tnf', 'CSF2']

# %%
gene_array = np.array(gene_matriz_lista)

# %%
gene_array.shape
gene_array [[0, 2]]
# Out:
# array([['IFNG', 'Il10', 'Tnf', 'CSF2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434']],
#       dtype='<U27')

# %%
gene_array[:,0]
# Out:
# array(['IFNG', 'interferon gamma', 'HGNC:HGNC:5438', 'protein coding',
#        'Homo sapiens', '12'], dtype='<U27')

# %%
gene_array[:, [1,2]]
# Out:
# array([['Il10', 'Tnf'],
#        ['interleukin 10', 'tumor necrosis factor'],
#        ['RGD:2886', 'MGI:MGI:104798'],
#        ['protein coding', 'protein coding'],
#        ['Rattus norvegicus', 'Mus musculus'],
#        ['13', '17']], dtype='<U27')
